# %%
import pandas as pd
import numpy as np
df = pd.read_csv('final_csv/bussinessweekly.csv')
df
# Out:
#                                                     URL        Date  \
# 0     https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 1     https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 2     https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 3     https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# 4     https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# ...                                                 ...         ...
# 1532  https://wealth.businessweekly.com.tw/GArticle....  2012/09/06
# 1533  https://wealth.businessweekly.com.tw/GArticle....  2012/08/30
# 1534  https://wealth.businessweekly.com.tw/GArticle....  2012/08/16
# 1535  https://wealth.businessweekly.com.tw/GArticle....  2012/06/29
# 1536  https://wealth.businessweekly.com.tw/GArticle....  2012/04/12
#
#                                             Title            Author  \
# 0                                 國安基金不退場，股市會過熱嗎？               陳唯泰
# ...

# %%
import re
for i in range(1535):
    if not (re.match(r'[0-9]{4}\/[0-9]{2}\/[0-9]{2}',df['Date'][i])):
        df['Date'][i] = df['Author'][i].replace('.','/')

# %%
for i in range(1535):
    if not (re.match(r'[0-9]{4}\/[0-9]{2}\/[0-9]{2}',df['Date'][i])):
        print(df['Date'][i])

# %%
df.dropna(subset=['Content'],inplace=True)
df.shape
# Out:
# (1535, 5)

# %%
df.to_csv('final_csv/bussinessweekly.csv', index=False)

# %%
df2 = pd.read_csv('final_csv/all_web.csv')
df2
# Out:
#                                                       URL        Date  \
# 0       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 1       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 2       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 3       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# 4       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# ...                                                   ...         ...
# 617249  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/16
# 617250  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/15
# 617251  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/12
# 617252  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/11
# 617253  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/10
#
#                                               Title        Author  \
# ...

# %%
df2.iloc[1535:1540,:]
# Out:
#                                                     URL        Date  \
# 1535  https://wealth.businessweekly.com.tw/GArticle....  2012/06/29
# 1536  https://wealth.businessweekly.com.tw/GArticle....  2012/04/12
# 1537         https://ctee.com.tw/news/stock/312137.html  2020/08/03
# 1538         https://ctee.com.tw/news/stock/312122.html  2020/08/03
# 1539         https://ctee.com.tw/news/stock/312096.html  2020/08/03
#
#                     Title            Author  \
# 1535         怎麼樣才能不上班也有錢？               李柏鋒
# 1536         當死薪水碰上通膨怎麼辦？  Buffettism (李柏鋒)
# 1537  聯發科第3季營收看增 2外資上修目標價               中央社
# 1538  盤中》台股大跌逾120點 回測10日線               中央社
# 1539           上市、櫃企業營運快報              數位編輯
#
#                                                 Content          Website
# 1535  Q到底什麼是財務自由A自從羅伯特清崎的富爸爸窮爸爸系列理財書籍在台灣上市以後許多人的人生終極...  bussinessweekly
# 1536  油電雙漲已經是無法改變的事實隨之而來的通貨膨脹物價上漲也是預料中事我們該怎麼理財才能打敗通膨...  bussinessweekly
# ...

# %%
df2.drop(index=range(1537),inplace=True)
df2
# Out:
#                                                       URL        Date  \
# 1537           https://ctee.com.tw/news/stock/312137.html  2020/08/03
# 1538           https://ctee.com.tw/news/stock/312122.html  2020/08/03
# 1539           https://ctee.com.tw/news/stock/312096.html  2020/08/03
# 1540           https://ctee.com.tw/news/stock/312094.html  2020/08/03
# 1541           https://ctee.com.tw/news/stock/312024.html  2020/08/03
# ...                                                   ...         ...
# 617249  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/16
# 617250  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/15
# 617251  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/12
# 617252  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/11
# 617253  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/10
#
#                            Title      Author  \
# 1537         聯發科第3季營收看增 2外資上修目標價         中央社
# ...

# %%
df_all = pd.concat([df,df2],ignore_index = False)

# %%
df_all
# Out:
#                                                       URL        Date  \
# 0       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 1       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 2       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 3       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# 4       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# ...                                                   ...         ...
# 617249  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/16
# 617250  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/15
# 617251  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/12
# 617252  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/11
# 617253  https://www.cmoney.tw/notes/note-detail.aspx?n...   2013/4/10
#
#                                               Title        Author  \
# ...

# %%
df_all.to_csv('./final_csv/all_web.csv', index=False)
