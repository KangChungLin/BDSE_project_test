# %%
import pandas as pd
import numpy as np
df = pd.read_csv('final_csv/all_web.csv')
df
# Out:
#                                                       URL        Date  \
# 0       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 1       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 2       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 3       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# 4       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# ...                                                   ...         ...
# 852362  https://www.businesstoday.com.tw/article/categ...  1998/11/19
# 852363  https://www.businesstoday.com.tw/article/categ...  1998/11/19
# 852364  https://www.businesstoday.com.tw/article/categ...  1998/11/12
# 852365  https://www.businesstoday.com.tw/article/categ...  1998/11/12
# 852366  https://www.businesstoday.com.tw/article/categ...  1998/11/05
#
#                                               Title        Author  \
# ...

# %%
ts = pd.DatetimeIndex(df['Date'][:10])

# %%
ts[ts < pd.Timestamp(2020,7,17)]
# Out:
# DatetimeIndex(['2020-07-15', '2020-07-15', '2020-07-15', '2020-07-14',
#                '2020-07-14'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors = 'coerce')

# %%
df['Date'][:10]
# Out:
# 0   2020-07-20
# 1   2020-07-20
# 2   2020-07-20
# 3   2020-07-17
# 4   2020-07-17
# 5   2020-07-15
# 6   2020-07-15
# 7   2020-07-15
# 8   2020-07-14
# 9   2020-07-14
# Name: Date, dtype: datetime64[ns]

# %%
df.loc[df['Date']>=pd.to_datetime('2020-07-20'),:]
# Out:
#                                                       URL       Date  \
# 0       https://wealth.businessweekly.com.tw/GArticle.... 2020-07-20
# 1       https://wealth.businessweekly.com.tw/GArticle.... 2020-07-20
# 2       https://wealth.businessweekly.com.tw/GArticle.... 2020-07-20
# 1535           https://ctee.com.tw/news/stock/312137.html 2020-08-03
# 1536           https://ctee.com.tw/news/stock/312122.html 2020-08-03
# ...                                                   ...        ...
# 846188  https://www.businesstoday.com.tw/article/categ... 2020-07-20
# 846189  https://www.businesstoday.com.tw/article/categ... 2020-07-20
# 846190  https://www.businesstoday.com.tw/article/categ... 2020-07-20
# 846191  https://www.businesstoday.com.tw/article/categ... 2020-07-20
# 846192  https://www.businesstoday.com.tw/article/categ... 2020-07-20
#
#                                                   Title         Author  \
# ...

# %%
df.loc[df['Date'].isnull(),:]['Website'].unique()
# Out:
# array(['moneydj', 'ptt'], dtype=object)

# %%
df.loc[df['Date'].isnull(),:].loc[df['Website']=='moneydj',:]
# Out:
#                                                       URL Date  \
# 486106  https://www.moneydj.com/forum/showtopic-166704...  NaT
# 486107  https://www.moneydj.com/forum/showtopic-166703...  NaT
# 486108  https://www.moneydj.com/forum/showtopic-166701...  NaT
# 486109  https://www.moneydj.com/forum/showtopic-166699...  NaT
# 486110  https://www.moneydj.com/forum/showtopic-166697...  NaT
# ...                                                   ...  ...
# 844287  https://www.moneydj.com/forum/showtopic-187229...  NaT
# 844288  https://www.moneydj.com/forum/showtopic-187215...  NaT
# 844289  https://www.moneydj.com/forum/showtopic-187214...  NaT
# 844398  https://www.moneydj.com/forum/showtopic-186293...  NaT
# 844399  https://www.moneydj.com/forum/showtopic-186282...  NaT
#
#                                                    Title     Author  \
# 486106                                       12檔KY股 買盤湧入      大昌廖維凌
# 486107                                   三大名師看台股後勢 免驚啦~~      大昌劉澤慧
# ...

# %%
df2 = pd.read_csv('final_csv/all_web.csv')
df2
# Out:
#                                                       URL        Date  \
# 0       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 1       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 2       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 3       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# 4       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# ...                                                   ...         ...
# 852362  https://www.businesstoday.com.tw/article/categ...  1998/11/19
# 852363  https://www.businesstoday.com.tw/article/categ...  1998/11/19
# 852364  https://www.businesstoday.com.tw/article/categ...  1998/11/12
# 852365  https://www.businesstoday.com.tw/article/categ...  1998/11/12
# 852366  https://www.businesstoday.com.tw/article/categ...  1998/11/05
#
#                                               Title        Author  \
# ...

# %%
df2.loc[df['Date'].isnull(),:]['Date'].unique()
# Out:
# array([':', ':2017/09/1908:12', ':2017/09/1908:10', ...,
#        ':2010/03/1315:33', ':2010/03/1509:50', ':2010/03/1514:22'],
#       dtype=object)

# %%
# 選出不合時間格式的資料
df2.loc[df['Date'].isnull(),:]
# Out:
#                                                       URL             Date  \
# 486106  https://www.moneydj.com/forum/showtopic-166704...                :
# 486107  https://www.moneydj.com/forum/showtopic-166703...                :
# 486108  https://www.moneydj.com/forum/showtopic-166701...                :
# 486109  https://www.moneydj.com/forum/showtopic-166699...                :
# 486110  https://www.moneydj.com/forum/showtopic-166697...                :
# ...                                                   ...              ...
# 844287  https://www.moneydj.com/forum/showtopic-187229...  2020/05/2011:40
# 844288  https://www.moneydj.com/forum/showtopic-187215...  2020/05/2009:31
# 844289  https://www.moneydj.com/forum/showtopic-187214...  2020/05/2008:24
# 844398  https://www.moneydj.com/forum/showtopic-186293...  2020/04/2015:19
# 844399  https://www.moneydj.com/forum/showtopic-186282...  2020/04/2011:47
#
# ...

# %%
# 擷取符合格式的部分 其餘為空值
df2.loc[df['Date'].isnull(),:]['Date'].str.findall('[0-9]{4}\/[0-9]{2}\/[0-9]{2}').str.get(0)
# Out:
# 486106           NaN
# 486107           NaN
# 486108           NaN
# 486109           NaN
# 486110           NaN
#              ...
# 844287    2020/05/20
# 844288    2020/05/20
# 844289    2020/05/20
# 844398    2020/04/20
# 844399    2020/04/20
# Name: Date, Length: 10964, dtype: object

# %%
i = df2.loc[df['Date'].isnull(),:].index

# %%
# loc好像只能寫一層
df2.loc[i,'Date'] = df2.loc[df['Date'].isnull(),:]['Date'].str.findall('[0-9]{4}\/[0-9]{2}\/[0-9]{2}').str.get(0)

# %%
df2.loc[df['Date'].isnull(),:]['Date']
# Out:
# 486106           NaN
# 486107           NaN
# 486108           NaN
# 486109           NaN
# 486110           NaN
#              ...
# 844287    2020/05/20
# 844288    2020/05/20
# 844289    2020/05/20
# 844398    2020/04/20
# 844399    2020/04/20
# Name: Date, Length: 10964, dtype: object

# %%
df2.loc[df2['Date'].isnull(),:]
# Out:
#                                                       URL Date  \
# 486106  https://www.moneydj.com/forum/showtopic-166704...  NaN
# 486107  https://www.moneydj.com/forum/showtopic-166703...  NaN
# 486108  https://www.moneydj.com/forum/showtopic-166701...  NaN
# 486109  https://www.moneydj.com/forum/showtopic-166699...  NaN
# 486110  https://www.moneydj.com/forum/showtopic-166697...  NaN
# ...                                                   ...  ...
# 839757  https://www.moneydj.com/forum/showtopic-154145...  NaN
# 839758  https://www.moneydj.com/forum/showtopic-154139...  NaN
# 839759  https://www.moneydj.com/forum/showtopic-154136...  NaN
# 839760  https://www.moneydj.com/forum/showtopic-154135...  NaN
# 839761  https://www.moneydj.com/forum/showtopic-154120...  NaN
#
#                             Title     Author  \
# 486106                12檔KY股 買盤湧入      大昌廖維凌
# 486107            三大名師看台股後勢 免驚啦~~      大昌劉澤慧
# 486108               台股攻勢暫歇 名師說免驚       大昌秋如
# ...

# %%
df2
# Out:
#                                                       URL        Date  \
# 0       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 1       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 2       https://wealth.businessweekly.com.tw/GArticle....  2020/07/20
# 3       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# 4       https://wealth.businessweekly.com.tw/GArticle....  2020/07/17
# ...                                                   ...         ...
# 852362  https://www.businesstoday.com.tw/article/categ...  1998/11/19
# 852363  https://www.businesstoday.com.tw/article/categ...  1998/11/19
# 852364  https://www.businesstoday.com.tw/article/categ...  1998/11/12
# 852365  https://www.businesstoday.com.tw/article/categ...  1998/11/12
# 852366  https://www.businesstoday.com.tw/article/categ...  1998/11/05
#
#                                               Title        Author  \
# ...

# %%
df2.to_csv('./final_csv/all_web_Date.csv', index=False)

# %%
import re
s = '2020/05/2008:24'
re.findall(r'[0-9]{4}\/[0-9]{2}\/[0-9]{2}',s)[0]
# Out:
# '2020/05/20'

# %%
df2.loc[df['Date'].isnull(),:].loc[df2['Date']==':',:]
# Out:
#                                                       URL Date  \
# 486106  https://www.moneydj.com/forum/showtopic-166704...    :
# 486107  https://www.moneydj.com/forum/showtopic-166703...    :
# 486108  https://www.moneydj.com/forum/showtopic-166701...    :
# 486109  https://www.moneydj.com/forum/showtopic-166699...    :
# 486110  https://www.moneydj.com/forum/showtopic-166697...    :
# ...                                                   ...  ...
# 839757  https://www.moneydj.com/forum/showtopic-154145...    :
# 839758  https://www.moneydj.com/forum/showtopic-154139...    :
# 839759  https://www.moneydj.com/forum/showtopic-154136...    :
# 839760  https://www.moneydj.com/forum/showtopic-154135...    :
# 839761  https://www.moneydj.com/forum/showtopic-154120...    :
#
#                             Title     Author  \
# 486106                12檔KY股 買盤湧入      大昌廖維凌
# 486107            三大名師看台股後勢 免驚啦~~      大昌劉澤慧
# 486108               台股攻勢暫歇 名師說免驚       大昌秋如
# ...

# %%
df2.loc[df['Date'].isnull(),:].loc[df2['Date']==':',:]['URL'][839760]
# Out:
# 'https://www.moneydj.com/forum/showtopic-154135.aspx'

# %%
df3 = pd.read_csv('moneydj/moneydjP_1100.csv')
df3
# Out:
#                                                      URL                Date  \
# 0      https://www.moneydj.com/forum/showtopic-176856...      2019/6/7 14:33
# 1      https://www.moneydj.com/forum/showtopic-176831...      2019/6/6 09:49
# 2      https://www.moneydj.com/forum/showtopic-176827...      2019/6/6 08:27
# 3      https://www.moneydj.com/forum/showtopic-176825...      2019/6/6 08:22
# 4      https://www.moneydj.com/forum/showtopic-176824...      2019/6/6 08:09
# ...                                                  ...                 ...
# 67907  https://www.moneydj.com/forum/showtopic-94151....  : 2013-12-02 18:50
# 67908  https://www.moneydj.com/forum/showtopic-94146....  : 2013-12-02 17:36
# 67909  https://www.moneydj.com/forum/showtopic-94140....  : 2013-12-02 16:00
# 67910  https://www.moneydj.com/forum/showtopic-94133....  : 2013-12-02 13:07
# 67911  https://www.moneydj.com/forum/showtopic-94130....  : 2013-12-02 12:01
#
# ...

# %%
df3.loc[df3['URL']=='https://www.moneydj.com/forum/showtopic-154135.aspx',:]
# Out:
#                                                      URL                Date  \
# 35871  https://www.moneydj.com/forum/showtopic-154135...  : 2017-09-19 11:12
#
#                           Title   Author  \
# 35871  顧立雄擬重查兆豐永豐金案 金融股跳水跌破周月季線  期貨選擇權女王
#
#                                                  Content
# 35871  經濟日報記者葉憶如即時報導金管會主委顧立雄報系資料照外資昨天原本大舉買超金融股不過金管會主委...
